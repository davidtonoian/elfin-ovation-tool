# %%
import elfin_ovation_tool.load_example as elfin_ovation

#to check on what version of pyspedas the example is built
import pyspedas
pyspedas.version()
# Out:
# 03-Feb-25 21:59:15: pyspedas version: 1.7.1

# %%
help(elfin_ovation)

# %%
#i - number of OVATION example spectra (from 0 to 22)
i = 0
tplot_vars = elfin_ovation.load_example(i)
tplot_vars
# Out:
# 03-Feb-25 21:59:15: ELFIN EPD: START LOADING.
# 03-Feb-25 21:59:15: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 03-Feb-25 21:59:16: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210512_v01.cdf
# 03-Feb-25 21:59:16: Unable to get ydata for variable ela_pef_Tspin
# 03-Feb-25 21:59:16: Variable ela_pef_hs_epa_spec DEPEND_1 attribute ela_pef_energies_mean has length 16, but corresponding data dimension has length 10. Removing attribute.
# 03-Feb-25 21:59:16: Variable ela_pef_fs_epa_spec DEPEND_1 attribute ela_pef_energies_mean has length 16, but corresponding data dimension has length 18. Removing attribute.
# 03-Feb-25 21:59:17: ELFIN EPD: LOADING END.
# 03-Feb-25 21:59:17: ELFIN EPD L2: START PROCESSING.
# 03-Feb-25 21:59:17: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 03-Feb-25 21:59:17: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# ...

# %%
elfin_ovation.summary_plot()
# Out:
# 03-Feb-25 21:59:25: ['gei', 'gse', 'gsm', 'sm']
# 03-Feb-25 21:59:25: Running transformation: subgei2gse
# 03-Feb-25 21:59:25: Running transformation: subgse2gsm
# 03-Feb-25 21:59:25: Running transformation: subgsm2sm
# 03-Feb-25 21:59:25: Output variable: ela_pos_sm

# %%
#creating figures for all examples
for i in range(0, 23):
    tplot_vars = elfin_ovation.load_example(i)
    elfin_ovation.summary_plot(f"./figs/summary_plot_{i}.png", )
# Out:
# 03-Feb-25 21:59:32: ELFIN EPD: START LOADING.
# 03-Feb-25 21:59:32: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 03-Feb-25 21:59:32: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210512_v01.cdf
# 03-Feb-25 21:59:32: Unable to get ydata for variable ela_pef_Tspin
# 03-Feb-25 21:59:32: Variable ela_pef_hs_epa_spec DEPEND_1 attribute ela_pef_energies_mean has length 16, but corresponding data dimension has length 10. Removing attribute.
# 03-Feb-25 21:59:32: Variable ela_pef_fs_epa_spec DEPEND_1 attribute ela_pef_energies_mean has length 16, but corresponding data dimension has length 18. Removing attribute.
# 03-Feb-25 21:59:33: ELFIN EPD: LOADING END.
# 03-Feb-25 21:59:33: ELFIN EPD L2: START PROCESSING.
# 03-Feb-25 21:59:33: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 03-Feb-25 21:59:33: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# ...
